# %% [markdown]
# ## VisualizingData
# <strong>Sales Data Analysis</strong> <br>
# Analyzing monthly product sales in 3 different ways.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import CSV of monthly sales
df = pd.read_csv("MonthlyProductSales.csv", encoding = "ISO-8859-1")

# %%
df
# Out:
#      Month of Order Date                                       Product Name  \
# 0             2013-05-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 1             2015-06-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2             2013-11-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3             2016-07-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 4             2016-11-01  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# ...                  ...                                                ...
# 9247          2016-06-01                         Zipper Ring Binder Pockets
# 9248          2016-07-01                         Zipper Ring Binder Pockets
# 9249          2013-04-01                         Zipper Ring Binder Pockets
# 9250          2016-12-01                         Zipper Ring Binder Pockets
# 9251          2013-07-01                         Zipper Ring Binder Pockets
#
#       Sales
# 0     208.0
# 1     208.0
# 2     333.0
# ...

# %% [markdown]
# ### i. Default plot

# %%
# plotting total sales by month

df.groupby(df['Month of Order Date']).sum().plot()
# Out:
# <AxesSubplot:xlabel='Month of Order Date'>

# %% [markdown]
# ### ii. Histogram plot

# %%
# plotting histogram over similar data

df.groupby(df['Month of Order Date']).sum().plot(kind='hist', bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Horizontal Bar plot

# %%
# groupby: Product name
# sort by: Sales sum
# fetching largest sales from bottom because of ascending order
# plot that data using horizontal bar visualization

df.groupby(df['Product Name']).sum().sort_values(by='Sales').tail(10).plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='Product Name'>
